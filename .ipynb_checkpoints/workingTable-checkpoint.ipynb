# %%
import pandas as pd
from IPython.display import display
import numpy as np


# To import the Excel Workbook
xls_file = pd.ExcelFile('HC_Jenny.xlsx')

# To select the Excel Worksheet of your interest
table = xls_file.parse('raw_code')
display(table)
# Out:
#       No     tm_IU  tm_Log       cb_IU    cb_Log   Run date Remarks
# 0      1   5170000    6.76   3480000.0  6.541579 2016-07-28     NaN
# 1      2   1440000    6.16    977000.0  5.989895 2016-07-28     NaN
# 2      3        15    1.18        15.0  1.176091 2016-07-28     NaN
# 3      4   6070000    6.78   2960000.0  6.471292 2016-07-28     NaN
# 4      5    535000    5.73    999000.0  5.999565 2016-07-28     NaN
# 5      6      4960    3.70      5600.0  3.748188 2016-07-28     NaN
# 6      7       124    2.09       179.0  2.252853 2016-07-28     NaN
# 7      8         0    0.00         0.0  0.000000 2016-07-28     NaN
# 8      9    819000    5.91   1360000.0  6.133539 2016-07-28     NaN
# 9     10   2740000    6.44   5440000.0  6.735599 2016-07-28     NaN
# 10    11        15    1.18        15.0  1.176091 2016-07-28     NaN
# 11    12     51600    4.71     87600.0  4.942504 2016-07-28     NaN
# 12    13         0    0.00         0.0  0.000000 2016-07-28     NaN
# 13    14   4700000    6.67   9480000.0  6.976808 2016-07-28     NaN
# 14    15     43900    4.64     32800.0  4.515874 2016-07-28     NaN
# 15    16        15    1.18        16.4  1.214844 2016-07-28     NaN
# 16    17       185    2.27       121.0  2.082785 2016-07-28     NaN
# 17    18        15    1.18         0.0  0.000000 2016-07-28     NaN
# 18    19   1550000    6.19   2790000.0  6.445604 2016-07-28     NaN
# 19    20  12300000    7.09  12300000.0  7.089905 2016-07-28      MJ
# 20    21   4260000    6.63   8930000.0  6.950851 2016-08-02     NaN
# 21    22   4350000    6.64   7840000.0  6.894316 2016-08-02     NaN
# 22    23    506000    5.70    983000.0  5.992554 2016-08-02     NaN
# 23    24   4910000    6.69   6120000.0  6.786751 2016-08-02     NaN
# 24    25     63500    4.80    135000.0  5.130334 2016-08-02     NaN
# 25    26   4120000    6.62   3140000.0  6.496930 2016-08-02     NaN
# 26    27   5390000    6.73   8740000.0  6.941511 2016-08-02     NaN
# 27    28   6100000    6.79   7090000.0  6.850646 2016-08-02     NaN
# 28    29   3060000    6.49   3700000.0  6.568202 2016-08-02     NaN
# 29    30   3160000    6.50   5210000.0  6.716838 2016-08-02     NaN
# ..   ...       ...     ...         ...       ...        ...     ...
# 82    83    134000    5.13    162000.0  5.209515 2016-11-08     NaN
# 83    84         0    0.00         0.0  0.000000 2016-11-08     NaN
# 84    85   3480000    6.54   3780000.0  6.577492 2016-11-08     NaN
# 85    86     33600    4.53     42600.0  4.629410 2016-11-08     NaN
# 86    87        15    1.18        20.9  1.320146 2016-11-08      MJ
# 87    88         0    0.00         0.0  0.000000 2018-03-01     NaN
# 88    89         0    0.00         0.0  0.000000 2018-03-01     NaN
# 89    90         0    0.00         0.0  0.000000 2018-03-02     NaN
# 90    91         0    0.00         0.0  0.000000 2018-03-02     NaN
# 91    92         0    0.00         0.0  0.000000 2018-03-02     NaN
# 92    93         0    0.00         0.0  0.000000 2018-03-02     NaN
# 93    94         0    0.00         0.0  0.000000 2018-03-05     NaN
# 94    95         0    0.00         0.0  0.000000 2018-03-05     NaN
# 95    96         0    0.00         0.0  0.000000 2018-03-05     NaN
# 96    97         0    0.00         0.0  0.000000 2018-02-22     NaN
# 97    98         0    0.00         0.0  0.000000 2018-02-22     NaN
# 98    99         0    0.00         0.0  0.000000 2018-02-22     NaN
# 99   100         0    0.00         0.0  0.000000 2018-02-23     NaN
# 100  101         0    0.00         0.0  0.000000 2018-02-23     NaN
# 101  102         0    0.00         0.0  0.000000 2018-02-23     NaN
# 102  103         0    0.00         0.0  0.000000 2018-02-23     NaN
# 103  104         0    0.00         0.0  0.000000 2018-02-26     NaN
# 104  105         0    0.00         0.0  0.000000 2018-02-26     NaN
# 105  106         0    0.00         0.0  0.000000 2018-02-26     NaN
# 106  107    760000    5.88    576000.0  5.760000 2018-03-02     NaN
# 107  108   1200000    6.08   1540000.0  6.190000 2018-03-02     NaN
# 108  109         0    0.00         0.0  0.000000 2018-02-26     NaN
# 109  110         0    0.00         0.0  0.000000 2018-02-26     NaN
# 110  111     11800    3.14      5960.0  3.950000 2018-02-26     NaN
# 111  112   1300000    6.11   1750000.0  6.240000 2018-02-26     NaN
#
# [112 rows x 7 columns]

# %%
# To select filter out data that less than 15 from the column1
df = table[table.tm_IU > 15]

# To select filter out data that less than 15 from the column2
df = df[df.cb_IU > 15]

# To count and verify total datapoint
df.count()
# Out:
# No          65
# tm_IU       65
# tm_Log      65
# cb_IU       65
# cb_Log      65
# Run date    65
# Remarks      1
# dtype: int64

# %%
import numpy as np

# To assign the values of column1 to x-axis
x = df['tm_Log']

# To assign the values of column2 to y-axis
y = df['cb_Log']

# To get the linear regression and print the best fit line formula (Minimal sum of square method). 
regression = np.polyfit(x, y, 1)
print('y =', regression[0], 'x +', regression[1])

# To get the correlation, r, for all the data.
display(df.corr())

# To get the correlation, r2, for the target of interest, column1 vs column2.
print('r2 =',(0.984582)**2)
# Out:
# y = 1.02352862714 x + -0.0269955217518
#               No     tm_IU    tm_Log     cb_IU    cb_Log
# No      1.000000 -0.080629 -0.167451 -0.035383 -0.144275
# tm_IU  -0.080629  1.000000  0.609965  0.949734  0.601205
# tm_Log -0.167451  0.609965  1.000000  0.535604  0.984582
# cb_IU  -0.035383  0.949734  0.535604  1.000000  0.549804
# cb_Log -0.144275  0.601205  0.984582  0.549804  1.000000
# r2 = 0.9694017147239999

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# A scatter plots for x vs y values
plt.figure(figsize=(15, 10))
sns.regplot(x=x, y=y, truncate=True)
plt.title('Comparison between cobas® HCV 6800 and COBAS® AmpliPrep/COBAS® TaqMan® HCV Test')
plt.xlabel('AmpliPrep/TaqMan (Log IU/mL)')
plt.ylabel('cobas HCV 6800 (Log IU/mL)')
plt.text(6, 3.8, r'y = 1.0235x - 0.0270')
plt.text(6, 3.5, r'r2 = 0.9694')
plt.show()

# %%
# To define function to generate bland_altman_plot
def bland_altman_plot(data1, data2, *args, **kwargs):
    data1     = np.asarray(data1)
    data2     = np.asarray(data2)
    mean      = np.mean([data1, data2], axis=0)
    diff      = data1 - data2                   # Difference between data1 and data2
    md        = np.mean(diff)                   # Mean of the difference
    sd        = np.std(diff, axis=0)            # Standard deviation of the difference
    
    # to print mean, mean+-2sd
    print(md)
    print(md+ 1.96*sd)
    print(md- 1.96*sd)
    
    plt.figure(figsize=(15, 10))
    plt.scatter(mean, diff, *args, **kwargs)
    plt.axhline(md,           color='gray', linestyle='--')
    plt.axhline(md + 1.96*sd, color='gray', linestyle='--')
    plt.axhline(md - 1.96*sd, color='gray', linestyle='--')

bland_altman_plot(y, x)
plt.title('Bland-Altman plot comparing the difference between the cobas® HCV 6800 and COBAS® AmpliPrep/COBAS® TaqMan® HCV Test')
plt.xlabel('Average of 2 measures')
plt.ylabel('Difference between 2 measures')
plt.text(1.2, 0.57, r'Upper limit of 95% CI (0.6363)')
plt.text(1.2, -0.5, r'Lower limit of 95% CI (-0.431)')
plt.text(1.2, 0.05, r'Mean difference (0.1025)')
plt.show()
# Out:
# 0.102506042024
# 0.636280936023
# -0.431268851974

# %%
table2 = xls_file.parse('StdComparison_raw')
display(table2)
# Out:
#     Run  Dilution_Factor        tm        cb    tm_Log    cb_Log  cb_Ct  \
# 0     1     1.000000e-10       NaN       NaN       NaN       NaN    NaN
# 1     1     1.000000e-09       NaN       NaN       NaN       NaN    NaN
# 2     1     1.000000e-08       NaN       NaN       NaN       NaN    NaN
# 3     1     1.000000e-07       NaN      16.1       NaN  1.206826  38.02
# 4     1     1.000000e-06      43.4      68.9  1.637490  1.838219  36.07
# 5     1     1.000000e-05       854       862  2.931458  2.935507  32.76
# 6     1     1.000000e-04      5590     11800  3.747412  4.071882  28.56
# 7     1     1.000000e-03     42400    141000  4.627366  5.149219  25.00
# 8     1     1.000000e-02    357000   1370000  5.552668  6.136721  21.04
# 9     1     1.000000e-01   3460000  13500000  6.539076  7.130334  17.99
# 10    1     1.000000e+00  46800000   >1.0E+8  7.670246       NaN  14.23
# 11    2     1.000000e-10       NaN       NaN       NaN       NaN    NaN
# 12    2     1.000000e-09       NaN       NaN       NaN       NaN    NaN
# 13    2     1.000000e-08       NaN       NaN       NaN       NaN    NaN
# 14    2     1.000000e-07  <1.50E+1       <15       NaN       NaN  39.18
# 15    2     1.000000e-06      71.5      92.4  1.854306  1.965672  35.98
# 16    2     1.000000e-05       859       912  2.933993  2.959995  32.24
# 17    2     1.000000e-04      5650     12000  3.752048  4.079181  28.46
# 18    2     1.000000e-03     45100    155000  4.654177  5.190332  24.79
# 19    2     1.000000e-02    453000   1480000  5.656098  6.170262  21.36
# 20    2     1.000000e-01   2640000  13200000  6.421604  7.120574  18.02
# 21    2     1.000000e+00  39500000   >1.0E+8  7.596597       NaN  14.88
# 22    3     1.000000e-10       NaN       NaN       NaN       NaN    NaN
# 23    3     1.000000e-09       NaN       NaN       NaN       NaN    NaN
# 24    3     1.000000e-08       NaN       NaN       NaN       NaN    NaN
# 25    3     1.000000e-07       NaN       <15       NaN       NaN  39.66
# 26    3     1.000000e-06       103       146  2.012837  2.164353  35.41
# 27    3     1.000000e-05       792       833  2.898725  2.920645  32.50
# 28    3     1.000000e-04      6550      8500  3.816241  3.929419  28.66
# 29    3     1.000000e-03     44800     89100  4.651278  4.949878  25.53
# 30    3     1.000000e-02    485000   1300000  5.685742  6.113943  21.34
# 31    3     1.000000e-01   4110000  13600000  6.613842  7.133539  18.04
# 32    3     1.000000e+00  45400000   >1.0E+8  7.657056       NaN  14.25
#
#     cb_IC_Ct  tm_Ct  tm_IC_Ct
# 0      36.56    NaN      31.5
# 1      36.42    NaN      31.5
# 2      37.03    NaN      31.2
# 3      36.46    NaN      31.5
# 4      36.57   36.0      31.4
# 5      36.90   32.9      31.7
# 6      36.52   30.3      31.4
# 7      36.62   27.0      30.7
# 8      36.09   23.6      30.1
# 9      36.53   19.8      29.5
# 10     36.27   16.4      29.9
# 11     36.84    NaN      31.9
# 12     37.31    NaN      31.6
# 13     37.17    NaN      31.8
# 14     37.07    NaN      31.7
# 15     36.90   35.8      31.7
# 16     36.46   32.8       3.6
# 17     36.44   30.5      31.7
# 18     36.56   27.1      30.9
# 19     36.52   23.4      30.2
# 20     36.52   20.5      29.7
# 21     37.21   16.7      30.0
# 22     37.14    NaN      31.7
# 23     37.22    NaN      31.5
# 24     36.54    NaN      31.8
# 25     36.83    NaN      31.7
# 26     36.99   35.4      31.8
# 27     36.58   33.0      31.8
# 28     36.13   30.0      31.7
# 29     36.48   27.1      30.9
# 30     36.31   23.4      30.4
# 31     36.59   20.0      29.9
# 32     36.54   16.6      30.1

# %%
df2 = table2.dropna(axis=0, how='any')

x = df2['tm_Log']
y = df2['cb_Log']
regression = np.polyfit(x, y, 1)
print(regression)

display(df2.corr())
print(0.997895**2)
# Out:
# [ 1.11765058 -0.16480704]
#                           Run  Dilution_Factor    tm_Log    cb_Log     cb_Ct  \
# Run              1.000000e+00    -2.578987e-17  0.027591 -0.001919  0.000662
# Dilution_Factor -2.578987e-17     1.000000e+00  0.702543  0.701638 -0.696789
# tm_Log           2.759133e-02     7.025434e-01  1.000000  0.997895 -0.997716
# cb_Log          -1.919072e-03     7.016380e-01  0.997895  1.000000 -0.999568
# cb_Ct            6.622313e-04    -6.967892e-01 -0.997716 -0.999568  1.000000
# cb_IC_Ct        -4.518660e-02    -3.240526e-02 -0.467083 -0.458389  0.483055
# tm_Ct           -8.880236e-03    -7.336041e-01 -0.997104 -0.997036  0.996833
# tm_IC_Ct         1.835306e-02     2.927725e-02  0.087004  0.106534 -0.100122
#
#                  cb_IC_Ct     tm_Ct  tm_IC_Ct
# Run             -0.045187 -0.008880  0.018353
# Dilution_Factor -0.032405 -0.733604  0.029277
# tm_Log          -0.467083 -0.997104  0.087004
# cb_Log          -0.458389 -0.997036  0.106534
# cb_Ct            0.483055  0.996833 -0.100122
# cb_IC_Ct         1.000000  0.447703  0.126600
# tm_Ct            0.447703  1.000000 -0.092569
# tm_IC_Ct         0.126600 -0.092569  1.000000
# 0.995794431025

# %%
display(df2)
# Out:
#     Run  Dilution_Factor       tm        cb    tm_Log    cb_Log  cb_Ct  \
# 4     1         0.000001     43.4      68.9  1.637490  1.838219  36.07
# 5     1         0.000010      854       862  2.931458  2.935507  32.76
# 6     1         0.000100     5590     11800  3.747412  4.071882  28.56
# 7     1         0.001000    42400    141000  4.627366  5.149219  25.00
# 8     1         0.010000   357000   1370000  5.552668  6.136721  21.04
# 9     1         0.100000  3460000  13500000  6.539076  7.130334  17.99
# 15    2         0.000001     71.5      92.4  1.854306  1.965672  35.98
# 16    2         0.000010      859       912  2.933993  2.959995  32.24
# 17    2         0.000100     5650     12000  3.752048  4.079181  28.46
# 18    2         0.001000    45100    155000  4.654177  5.190332  24.79
# 19    2         0.010000   453000   1480000  5.656098  6.170262  21.36
# 20    2         0.100000  2640000  13200000  6.421604  7.120574  18.02
# 26    3         0.000001      103       146  2.012837  2.164353  35.41
# 27    3         0.000010      792       833  2.898725  2.920645  32.50
# 28    3         0.000100     6550      8500  3.816241  3.929419  28.66
# 29    3         0.001000    44800     89100  4.651278  4.949878  25.53
# 30    3         0.010000   485000   1300000  5.685742  6.113943  21.34
# 31    3         0.100000  4110000  13600000  6.613842  7.133539  18.04
#
#     cb_IC_Ct  tm_Ct  tm_IC_Ct
# 4      36.57   36.0      31.4
# 5      36.90   32.9      31.7
# 6      36.52   30.3      31.4
# 7      36.62   27.0      30.7
# 8      36.09   23.6      30.1
# 9      36.53   19.8      29.5
# 15     36.90   35.8      31.7
# 16     36.46   32.8       3.6
# 17     36.44   30.5      31.7
# 18     36.56   27.1      30.9
# 19     36.52   23.4      30.2
# 20     36.52   20.5      29.7
# 26     36.99   35.4      31.8
# 27     36.58   33.0      31.8
# 28     36.13   30.0      31.7
# 29     36.48   27.1      30.9
# 30     36.31   23.4      30.4
# 31     36.59   20.0      29.9

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15, 10))
sns.regplot(x=x, y=y, truncate=True)
plt.title('Comparison of standards quantification by cobas® HCV 6800 and COBAS® AmpliPrep/COBAS® TaqMan® HCV')
plt.xlabel('AmpliPrep/TaqMan (Log IU/mL)')
plt.ylabel('cobas (Log IU/mL)')
plt.text(6, 3.8, r'y = 1.1177x - 0.1648')
plt.text(6, 3.5, r'r2 = 0.9958')
plt.show()

# %%
df2['Log_Dilution_Factor'] = np.log10(df2['Dilution_Factor'])
x2 = df2['Log_Dilution_Factor']
y2 = df2['cb_Ct']
regression = np.polyfit(x2, y2, 1)
print(regression)

display(df2.corr())
print((-0.999133)**2)

plt.figure(figsize=(15, 10))
sns.regplot(x=x2, y=y2, truncate=True)
plt.title('Spread of Ct values of Standards by the cobas® HCV 6800')
plt.xlabel('Dilution factors')
plt.ylabel('Ct values of cobas')
plt.text(-2.1, 32, r'y = -3.6066x + 14.252')
plt.text(-2.1, 31, r'r2 = 0.9983')
plt.show()
# Out:
# [ -3.60657143  14.252     ]
# /Users/leehongkai/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                               Run  Dilution_Factor    tm_Log    cb_Log  \
# Run                  1.000000e+00    -2.578987e-17  0.027591 -0.001919
# Dilution_Factor     -2.578987e-17     1.000000e+00  0.702543  0.701638
# tm_Log               2.759133e-02     7.025434e-01  1.000000  0.997895
# cb_Log              -1.919072e-03     7.016380e-01  0.997895  1.000000
# cb_Ct                6.622313e-04    -6.967892e-01 -0.997716 -0.999568
# cb_IC_Ct            -4.518660e-02    -3.240526e-02 -0.467083 -0.458389
# tm_Ct               -8.880236e-03    -7.336041e-01 -0.997104 -0.997036
# tm_IC_Ct             1.835306e-02     2.927725e-02  0.087004  0.106534
# Log_Dilution_Factor  0.000000e+00     7.074817e-01  0.998344  0.998921
#
#                         cb_Ct  cb_IC_Ct     tm_Ct  tm_IC_Ct  \
# Run                  0.000662 -0.045187 -0.008880  0.018353
# Dilution_Factor     -0.696789 -0.032405 -0.733604  0.029277
# tm_Log              -0.997716 -0.467083 -0.997104  0.087004
# cb_Log              -0.999568 -0.458389 -0.997036  0.106534
# cb_Ct                1.000000  0.483055  0.996833 -0.100122
# cb_IC_Ct             0.483055  1.000000  0.447703  0.126600
# tm_Ct                0.996833  0.447703  1.000000 -0.092569
# tm_IC_Ct            -0.100122  0.126600 -0.092569  1.000000
# Log_Dilution_Factor -0.999133 -0.474553 -0.997708  0.101938
#
#                      Log_Dilution_Factor
# Run                             0.000000
# Dilution_Factor                 0.707482
# tm_Log                          0.998344
# cb_Log                          0.998921
# cb_Ct                          -0.999133
# cb_IC_Ct                       -0.474553
# tm_Ct                          -0.997708
# tm_IC_Ct                        0.101938
# Log_Dilution_Factor             1.000000
# 0.9982667516890001

# %%
y3 = df2['tm_Ct']
regression = np.polyfit(x2, y3, 1)
print(regression)

display(df2.corr())
print((-0.997708)**2)

plt.figure(figsize=(15, 10))
sns.regplot(x=x2, y=y3, truncate=True)
plt.title('Spread of Ct values of Standards by the COBAS® AmpliPrep/COBAS® TaqMan® HCV')
plt.xlabel('Dilution factors')
plt.ylabel('Ct values of Artus')
plt.text(-2.1, 34, r'y = -3.1333x + 17.2889')
plt.text(-2.1, 33, r'r2 = 0.9954')
plt.show()
# Out:
# [ -3.13333333  17.28888889]
#                               Run  Dilution_Factor    tm_Log    cb_Log  \
# Run                  1.000000e+00    -2.578987e-17  0.027591 -0.001919
# Dilution_Factor     -2.578987e-17     1.000000e+00  0.702543  0.701638
# tm_Log               2.759133e-02     7.025434e-01  1.000000  0.997895
# cb_Log              -1.919072e-03     7.016380e-01  0.997895  1.000000
# cb_Ct                6.622313e-04    -6.967892e-01 -0.997716 -0.999568
# cb_IC_Ct            -4.518660e-02    -3.240526e-02 -0.467083 -0.458389
# tm_Ct               -8.880236e-03    -7.336041e-01 -0.997104 -0.997036
# tm_IC_Ct             1.835306e-02     2.927725e-02  0.087004  0.106534
# Log_Dilution_Factor  0.000000e+00     7.074817e-01  0.998344  0.998921
#
#                         cb_Ct  cb_IC_Ct     tm_Ct  tm_IC_Ct  \
# Run                  0.000662 -0.045187 -0.008880  0.018353
# Dilution_Factor     -0.696789 -0.032405 -0.733604  0.029277
# tm_Log              -0.997716 -0.467083 -0.997104  0.087004
# cb_Log              -0.999568 -0.458389 -0.997036  0.106534
# cb_Ct                1.000000  0.483055  0.996833 -0.100122
# cb_IC_Ct             0.483055  1.000000  0.447703  0.126600
# tm_Ct                0.996833  0.447703  1.000000 -0.092569
# tm_IC_Ct            -0.100122  0.126600 -0.092569  1.000000
# Log_Dilution_Factor -0.999133 -0.474553 -0.997708  0.101938
#
#                      Log_Dilution_Factor
# Run                             0.000000
# Dilution_Factor                 0.707482
# tm_Log                          0.998344
# cb_Log                          0.998921
# cb_Ct                          -0.999133
# cb_IC_Ct                       -0.474553
# tm_Ct                          -0.997708
# tm_IC_Ct                        0.101938
# Log_Dilution_Factor             1.000000
# 0.9954212532640001
