# %%
import pandas as pd
from IPython.display import display
import numpy as np


# To import the Excel Workbook
xls_file = pd.ExcelFile('HCV_Jenny.xlsx')

# To select the Excel Worksheet of your interest
table = xls_file.parse('raw_code')
display(table)
# Out:
#       No   Accession  Taqman_IU  Taqman_Log    cobas_IU  cobas_Log   Run date  \
# 0      1  4066649110    5170000        6.76   3480000.0   6.541579 2016-07-28
# 1      2  6063468557    1440000        6.16    977000.0   5.989895 2016-07-28
# 2      3  6062136618         15        1.18        15.0   1.176091 2016-07-28
# 3      4  6062135857    6070000        6.78   2960000.0   6.471292 2016-07-28
# 4      5  6062136614     535000        5.73    999000.0   5.999565 2016-07-28
# 5      6  6062141817       4960        3.70      5600.0   3.748188 2016-07-28
# 6      7  6062141812        124        2.09       179.0   2.252853 2016-07-28
# 7      8  6062141811          0        0.00         0.0   0.000000 2016-07-28
# 8      9  6062140818     819000        5.91   1360000.0   6.133539 2016-07-28
# 9     10  6062140519    2740000        6.44   5440000.0   6.735599 2016-07-28
# 10    11  6062140910         15        1.18        15.0   1.176091 2016-07-28
# 11    12  6066601162      51600        4.71     87600.0   4.942504 2016-07-28
# 12    13  6056593528          0        0.00         0.0   0.000000 2016-07-28
# 13    14  6063453476    4700000        6.67   9480000.0   6.976808 2016-07-28
# 14    15  6062134683      43900        4.64     32800.0   4.515874 2016-07-28
# 15    16  6066641122         15        1.18        16.4   1.214844 2016-07-28
# 16    17  6062135154        185        2.27       121.0   2.082785 2016-07-28
# 17    18  6063477339         15        1.18         0.0   0.000000 2016-07-28
# 18    19  6062139608    1550000        6.19   2790000.0   6.445604 2016-07-28
# 19    20  6066606684   12300000        7.09  12300000.0   7.089905 2016-07-28
# 20    21  6066606851    4260000        6.63   8930000.0   6.950851 2016-08-02
# 21    22  6062129538    4350000        6.64   7840000.0   6.894316 2016-08-02
# 22    23  6062130087     506000        5.70    983000.0   5.992554 2016-08-02
# 23    24  6062130773    4910000        6.69   6120000.0   6.786751 2016-08-02
# 24    25  6062131944      63500        4.80    135000.0   5.130334 2016-08-02
# 25    26  6062132169    4120000        6.62   3140000.0   6.496930 2016-08-02
# 26    27  6062132570    5390000        6.73   8740000.0   6.941511 2016-08-02
# 27    28  6063441355    6100000        6.79   7090000.0   6.850646 2016-08-02
# 28    29  6072160350    3060000        6.49   3700000.0   6.568202 2016-08-02
# 29    30  4113794134    3160000        6.50   5210000.0   6.716838 2016-08-02
# ..   ...         ...        ...         ...         ...        ...        ...
# 82    83  4112130210     134000        5.13    162000.0   5.209515 2016-11-08
# 83    84  6072152933          0        0.00         0.0   0.000000 2016-11-08
# 84    85  6072152924    3480000        6.54   3780000.0   6.577492 2016-11-08
# 85    86  6082428180      33600        4.53     42600.0   4.629410 2016-11-08
# 86    87  6082165170         15        1.18        20.9   1.320146 2016-11-08
# 87    88  8033429219          0        0.00         0.0   0.000000 2018-03-01
# 88    89  8032125522          0        0.00         0.0   0.000000 2018-03-01
# 89    90  8036572262          0        0.00         0.0   0.000000 2018-03-02
# 90    91  8036572942          0        0.00         0.0   0.000000 2018-03-02
# 91    92  8036572857          0        0.00         0.0   0.000000 2018-03-02
# 92    93  8032126489          0        0.00         0.0   0.000000 2018-03-02
# 93    94  8036580350          0        0.00         0.0   0.000000 2018-03-05
# 94    95  8036580711          0        0.00         0.0   0.000000 2018-03-05
# 95    96  8032127280          0        0.00         0.0   0.000000 2018-03-05
# 96    97  8026540045          0        0.00         0.0   0.000000 2018-02-22
# 97    98  8023699752          0        0.00         0.0   0.000000 2018-02-22
# 98    99  8023401742          0        0.00         0.0   0.000000 2018-02-22
# 99   100  8022122001          0        0.00         0.0   0.000000 2018-02-23
# 100  101  8026545693          0        0.00         0.0   0.000000 2018-02-23
# 101  102  8022122118          0        0.00         0.0   0.000000 2018-02-23
# 102  103  8022122378          0        0.00         0.0   0.000000 2018-02-23
# 103  104  8026553231          0        0.00         0.0   0.000000 2018-02-26
# 104  105  8026553765          0        0.00         0.0   0.000000 2018-02-26
# 105  106  8022123195          0        0.00         0.0   0.000000 2018-02-26
# 106  107  8036574677     760000        5.88    576000.0   5.760000 2018-03-02
# 107  108  8036574009    1200000        6.08   1540000.0   6.190000 2018-03-02
# 108  109  8022123203          0        0.00         0.0   0.000000 2018-02-26
# 109  110  8022123457          0        0.00         0.0   0.000000 2018-02-26
# 110  111  8026555327      11800        3.14      5960.0   3.950000 2018-02-26
# 111  112  8022123289    1300000        6.11   1750000.0   6.240000 2018-02-26
#
#     Remarks
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19       MJ
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# ..      ...
# 82      NaN
# 83      NaN
# 84      NaN
# 85      NaN
# 86       MJ
# 87      NaN
# 88      NaN
# 89      NaN
# 90      NaN
# 91      NaN
# 92      NaN
# 93      NaN
# 94      NaN
# 95      NaN
# 96      NaN
# 97      NaN
# 98      NaN
# 99      NaN
# 100     NaN
# 101     NaN
# 102     NaN
# 103     NaN
# 104     NaN
# 105     NaN
# 106     NaN
# 107     NaN
# 108     NaN
# 109     NaN
# 110     NaN
# 111     NaN
#
# [112 rows x 8 columns]

# %%
# To select filter out data that less than 15 from the column1
df = table[table.Taqman_IU > 15]

# To select filter out data that less than 15 from the column2
df = df[df.cobas_IU > 15]

# To count and verify total datapoint
df.count()
# Out:
# No            65
# Accession     65
# Taqman_IU     65
# Taqman_Log    65
# cobas_IU      65
# cobas_Log     65
# Run date      65
# Remarks        1
# dtype: int64

# %%
import numpy as np

# To assign the values of column1 to x-axis
x = df['Taqman_Log']

# To assign the values of column2 to y-axis
y = df['cobas_Log']

# To get the linear regression and print the best fit line formula (Minimal sum of square method). 
regression = np.polyfit(x, y, 1)
print('y =', regression[0], 'x +', regression[1])

# To get the correlation, r, for all the data.
display(df.corr())

# To get the correlation, r2, for the target of interest, column1 vs column2.
print('r2 =',(0.984582)**2)
# Out:
# y = 1.02352862714 x + -0.0269955217518
#                   No  Accession  Taqman_IU  Taqman_Log  cobas_IU  cobas_Log
# No          1.000000   0.153737  -0.080629   -0.167451 -0.035383  -0.144275
# Accession   0.153737   1.000000  -0.156788    0.045708 -0.178486   0.053288
# Taqman_IU  -0.080629  -0.156788   1.000000    0.609965  0.949734   0.601205
# Taqman_Log -0.167451   0.045708   0.609965    1.000000  0.535604   0.984582
# cobas_IU   -0.035383  -0.178486   0.949734    0.535604  1.000000   0.549804
# cobas_Log  -0.144275   0.053288   0.601205    0.984582  0.549804   1.000000
# r2 = 0.9694017147239999

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# A scatter plots for x vs y values
plt.figure(figsize=(15, 10))
sns.regplot(x=x, y=y, truncate=True)
plt.title('Comparison between cobas® HCV 6800 and COBAS® AmpliPrep/COBAS® TaqMan® HCV Test')
plt.xlabel('AmpliPrep/TaqMan (Log IU/mL)')
plt.ylabel('cobas HCV 6800 (Log IU/mL)')
plt.text(6, 3.8, r'y = 1.0235x - 0.0270')
plt.text(6, 3.5, r'r2 = 0.9694')
plt.show()

# %%
# To define function to generate bland_altman_plot
def bland_altman_plot(data1, data2, *args, **kwargs):
    data1     = np.asarray(data1)
    data2     = np.asarray(data2)
    mean      = np.mean([data1, data2], axis=0)
    diff      = data1 - data2                   # Difference between data1 and data2
    md        = np.mean(diff)                   # Mean of the difference
    sd        = np.std(diff, axis=0)            # Standard deviation of the difference
    
    # to print mean, mean+-2sd
    print(md)
    print(md+ 1.96*sd)
    print(md- 1.96*sd)
    
    plt.figure(figsize=(15, 10))
    plt.scatter(mean, diff, *args, **kwargs)
    plt.axhline(md,           color='gray', linestyle='--')
    plt.axhline(md + 1.96*sd, color='gray', linestyle='--')
    plt.axhline(md - 1.96*sd, color='gray', linestyle='--')

bland_altman_plot(y, x)
plt.title('Bland-Altman plot comparing the difference between the cobas® HCV 6800 and COBAS® AmpliPrep/COBAS® TaqMan® HCV Test')
plt.xlabel('Average of 2 measures')
plt.ylabel('Difference between 2 measures')
plt.text(1.2, 0.57, r'Upper limit of 95% CI (0.6363)')
plt.text(1.2, -0.5, r'Lower limit of 95% CI (-0.431)')
plt.text(1.2, 0.05, r'Mean difference (0.1025)')
plt.show()
# Out:
# 0.102506042024
# 0.636280936023
# -0.431268851974

# %%
table2 = xls_file.parse('StdComparison_raw')
display(table2)
# Out:
#     Run  Dilution_Factor AmpliPrep     cobas  AmpliPrep_Log  cobas_Log  \
# 0     1     1.000000e-10       NaN       NaN            NaN        NaN
# 1     1     1.000000e-09       NaN       NaN            NaN        NaN
# 2     1     1.000000e-08       NaN       NaN            NaN        NaN
# 3     1     1.000000e-07       NaN      16.1            NaN   1.206826
# 4     1     1.000000e-06      43.4      68.9       1.637490   1.838219
# 5     1     1.000000e-05       854       862       2.931458   2.935507
# 6     1     1.000000e-04      5590     11800       3.747412   4.071882
# 7     1     1.000000e-03     42400    141000       4.627366   5.149219
# 8     1     1.000000e-02    357000   1370000       5.552668   6.136721
# 9     1     1.000000e-01   3460000  13500000       6.539076   7.130334
# 10    1     1.000000e+00  46800000   >1.0E+8       7.670246        NaN
# 11    2     1.000000e-10       NaN       NaN            NaN        NaN
# 12    2     1.000000e-09       NaN       NaN            NaN        NaN
# 13    2     1.000000e-08       NaN       NaN            NaN        NaN
# 14    2     1.000000e-07  <1.50E+1       <15            NaN        NaN
# 15    2     1.000000e-06      71.5      92.4       1.854306   1.965672
# 16    2     1.000000e-05       859       912       2.933993   2.959995
# 17    2     1.000000e-04      5650     12000       3.752048   4.079181
# 18    2     1.000000e-03     45100    155000       4.654177   5.190332
# 19    2     1.000000e-02    453000   1480000       5.656098   6.170262
# 20    2     1.000000e-01   2640000  13200000       6.421604   7.120574
# 21    2     1.000000e+00  39500000   >1.0E+8       7.596597        NaN
# 22    3     1.000000e-10       NaN       NaN            NaN        NaN
# 23    3     1.000000e-09       NaN       NaN            NaN        NaN
# 24    3     1.000000e-08       NaN       NaN            NaN        NaN
# 25    3     1.000000e-07       NaN       <15            NaN        NaN
# 26    3     1.000000e-06       103       146       2.012837   2.164353
# 27    3     1.000000e-05       792       833       2.898725   2.920645
# 28    3     1.000000e-04      6550      8500       3.816241   3.929419
# 29    3     1.000000e-03     44800     89100       4.651278   4.949878
# 30    3     1.000000e-02    485000   1300000       5.685742   6.113943
# 31    3     1.000000e-01   4110000  13600000       6.613842   7.133539
# 32    3     1.000000e+00  45400000   >1.0E+8       7.657056        NaN
#
#     cobas_Ct  cobas_IC_Ct  AmpliPrep_Ct  AmpliPrep_IC_Ct
# 0        NaN        36.56           NaN             31.5
# 1        NaN        36.42           NaN             31.5
# 2        NaN        37.03           NaN             31.2
# 3      38.02        36.46           NaN             31.5
# 4      36.07        36.57          36.0             31.4
# 5      32.76        36.90          32.9             31.7
# 6      28.56        36.52          30.3             31.4
# 7      25.00        36.62          27.0             30.7
# 8      21.04        36.09          23.6             30.1
# 9      17.99        36.53          19.8             29.5
# 10     14.23        36.27          16.4             29.9
# 11       NaN        36.84           NaN             31.9
# 12       NaN        37.31           NaN             31.6
# 13       NaN        37.17           NaN             31.8
# 14     39.18        37.07           NaN             31.7
# 15     35.98        36.90          35.8             31.7
# 16     32.24        36.46          32.8              3.6
# 17     28.46        36.44          30.5             31.7
# 18     24.79        36.56          27.1             30.9
# 19     21.36        36.52          23.4             30.2
# 20     18.02        36.52          20.5             29.7
# 21     14.88        37.21          16.7             30.0
# 22       NaN        37.14           NaN             31.7
# 23       NaN        37.22           NaN             31.5
# 24       NaN        36.54           NaN             31.8
# 25     39.66        36.83           NaN             31.7
# 26     35.41        36.99          35.4             31.8
# 27     32.50        36.58          33.0             31.8
# 28     28.66        36.13          30.0             31.7
# 29     25.53        36.48          27.1             30.9
# 30     21.34        36.31          23.4             30.4
# 31     18.04        36.59          20.0             29.9
# 32     14.25        36.54          16.6             30.1

# %%
df2 = table2.dropna(axis=0, how='any')

x = df2['AmpliPrep_Log']
y = df2['cobas_Log']
regression = np.polyfit(x, y, 1)
print(regression)

display(df2.corr())
print(0.998692**2)
# Out:
# [ 1.11765058 -0.16480704]
#                           Run  Dilution_Factor  AmpliPrep_Log  cobas_Log  \
# Run              1.000000e+00    -2.578987e-17       0.027591  -0.001919
# Dilution_Factor -2.578987e-17     1.000000e+00       0.702543   0.701638
# AmpliPrep_Log    2.759133e-02     7.025434e-01       1.000000   0.997895
# cobas_Log       -1.919072e-03     7.016380e-01       0.997895   1.000000
# cobas_Ct         6.622313e-04    -6.967892e-01      -0.997716  -0.999568
# cobas_IC_Ct     -4.518660e-02    -3.240526e-02      -0.467083  -0.458389
# AmpliPrep_Ct    -8.880236e-03    -7.336041e-01      -0.997104  -0.997036
# AmpliPrep_IC_Ct  1.835306e-02     2.927725e-02       0.087004   0.106534
#
#                  cobas_Ct  cobas_IC_Ct  AmpliPrep_Ct  AmpliPrep_IC_Ct
# Run              0.000662    -0.045187     -0.008880         0.018353
# Dilution_Factor -0.696789    -0.032405     -0.733604         0.029277
# AmpliPrep_Log   -0.997716    -0.467083     -0.997104         0.087004
# cobas_Log       -0.999568    -0.458389     -0.997036         0.106534
# cobas_Ct         1.000000     0.483055      0.996833        -0.100122
# cobas_IC_Ct      0.483055     1.000000      0.447703         0.126600
# AmpliPrep_Ct     0.996833     0.447703      1.000000        -0.092569
# AmpliPrep_IC_Ct -0.100122     0.126600     -0.092569         1.000000
# 0.9973857108640001

# %%
display(df2)
# Out:
#     Run  Dilution_Factor AmpliPrep     cobas  AmpliPrep_Log  cobas_Log  \
# 4     1         0.000001      43.4      68.9       1.637490   1.838219
# 5     1         0.000010       854       862       2.931458   2.935507
# 6     1         0.000100      5590     11800       3.747412   4.071882
# 7     1         0.001000     42400    141000       4.627366   5.149219
# 8     1         0.010000    357000   1370000       5.552668   6.136721
# 9     1         0.100000   3460000  13500000       6.539076   7.130334
# 15    2         0.000001      71.5      92.4       1.854306   1.965672
# 16    2         0.000010       859       912       2.933993   2.959995
# 17    2         0.000100      5650     12000       3.752048   4.079181
# 18    2         0.001000     45100    155000       4.654177   5.190332
# 19    2         0.010000    453000   1480000       5.656098   6.170262
# 20    2         0.100000   2640000  13200000       6.421604   7.120574
# 26    3         0.000001       103       146       2.012837   2.164353
# 27    3         0.000010       792       833       2.898725   2.920645
# 28    3         0.000100      6550      8500       3.816241   3.929419
# 29    3         0.001000     44800     89100       4.651278   4.949878
# 30    3         0.010000    485000   1300000       5.685742   6.113943
# 31    3         0.100000   4110000  13600000       6.613842   7.133539
#
#     cobas_Ct  cobas_IC_Ct  AmpliPrep_Ct  AmpliPrep_IC_Ct
# 4      36.07        36.57          36.0             31.4
# 5      32.76        36.90          32.9             31.7
# 6      28.56        36.52          30.3             31.4
# 7      25.00        36.62          27.0             30.7
# 8      21.04        36.09          23.6             30.1
# 9      17.99        36.53          19.8             29.5
# 15     35.98        36.90          35.8             31.7
# 16     32.24        36.46          32.8              3.6
# 17     28.46        36.44          30.5             31.7
# 18     24.79        36.56          27.1             30.9
# 19     21.36        36.52          23.4             30.2
# 20     18.02        36.52          20.5             29.7
# 26     35.41        36.99          35.4             31.8
# 27     32.50        36.58          33.0             31.8
# 28     28.66        36.13          30.0             31.7
# 29     25.53        36.48          27.1             30.9
# 30     21.34        36.31          23.4             30.4
# 31     18.04        36.59          20.0             29.9

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15, 10))
sns.regplot(x=x, y=y, truncate=True)
plt.title('Comparison of standards quantification by cobas® HCV 6800 and COBAS® AmpliPrep/COBAS® TaqMan® HCV Test')
plt.xlabel('AmpliPrep/TaqMan (Log IU/mL)')
plt.ylabel('cobas (Log IU/mL)')
plt.text(6, 3.8, r'y = 1.1177x - 0.1648')
plt.text(6, 3.5, r'r2 = 0.9974')
plt.show()

# %%
df2['Log_Dilution_Factor'] = np.log10(df2['Dilution_Factor'])
x = df2['Log_Dilution_Factor']
y = df2['cobas_Ct']
regression = np.polyfit(x, y, 1)
print(regression)

display(df2.corr())
print(0.999172**2)

plt.figure(figsize=(15, 10))
sns.regplot(x=x, y=y, truncate=True)
plt.title('Spread of Ct values of Standards by the cobas® HBV 6800')
plt.xlabel('Dilution factors')
plt.ylabel('Ct values of cobas')
plt.text(-2.1, 32, r'y = -3.462x + 12.383')
plt.text(-2.1, 31, r'r2 = 0.9983')
plt.show()
# Out:
# [ -3.60657143  14.252     ]
# /Users/leehongkai/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                               Run  Dilution_Factor  AmpliPrep_Log  cobas_Log  \
# Run                  1.000000e+00    -2.578987e-17       0.027591  -0.001919
# Dilution_Factor     -2.578987e-17     1.000000e+00       0.702543   0.701638
# AmpliPrep_Log        2.759133e-02     7.025434e-01       1.000000   0.997895
# cobas_Log           -1.919072e-03     7.016380e-01       0.997895   1.000000
# cobas_Ct             6.622313e-04    -6.967892e-01      -0.997716  -0.999568
# cobas_IC_Ct         -4.518660e-02    -3.240526e-02      -0.467083  -0.458389
# AmpliPrep_Ct        -8.880236e-03    -7.336041e-01      -0.997104  -0.997036
# AmpliPrep_IC_Ct      1.835306e-02     2.927725e-02       0.087004   0.106534
# Log_Dilution_Factor  0.000000e+00     7.074817e-01       0.998344   0.998921
#
#                      cobas_Ct  cobas_IC_Ct  AmpliPrep_Ct  AmpliPrep_IC_Ct  \
# Run                  0.000662    -0.045187     -0.008880         0.018353
# Dilution_Factor     -0.696789    -0.032405     -0.733604         0.029277
# AmpliPrep_Log       -0.997716    -0.467083     -0.997104         0.087004
# cobas_Log           -0.999568    -0.458389     -0.997036         0.106534
# cobas_Ct             1.000000     0.483055      0.996833        -0.100122
# cobas_IC_Ct          0.483055     1.000000      0.447703         0.126600
# AmpliPrep_Ct         0.996833     0.447703      1.000000        -0.092569
# AmpliPrep_IC_Ct     -0.100122     0.126600     -0.092569         1.000000
# Log_Dilution_Factor -0.999133    -0.474553     -0.997708         0.101938
#
#                      Log_Dilution_Factor
# Run                             0.000000
# Dilution_Factor                 0.707482
# AmpliPrep_Log                   0.998344
# cobas_Log                       0.998921
# cobas_Ct                       -0.999133
# cobas_IC_Ct                    -0.474553
# AmpliPrep_Ct                   -0.997708
# AmpliPrep_IC_Ct                 0.101938
# Log_Dilution_Factor             1.000000
# 0.9983446855839999

# %%
y = df2['AmpliPrep_Ct']
regression = np.polyfit(x, y, 1)
print(regression)

display(df2.corr())
print(0.998579**2)

plt.figure(figsize=(15, 10))
sns.regplot(x=x, y=y, truncate=True)
plt.title('Spread of Ct values of Standards by the Artus HBV RGQ Quantitative')
plt.xlabel('Dilution factors')
plt.ylabel('Ct values of Artus')
plt.text(-2.1, 34, r'y = -3.476x + 16.422')
plt.text(-2.1, 33, r'r2 = 0.997')
plt.show()
# Out:
# [ -3.13333333  17.28888889]
#                               Run  Dilution_Factor  AmpliPrep_Log  cobas_Log  \
# Run                  1.000000e+00    -2.578987e-17       0.027591  -0.001919
# Dilution_Factor     -2.578987e-17     1.000000e+00       0.702543   0.701638
# AmpliPrep_Log        2.759133e-02     7.025434e-01       1.000000   0.997895
# cobas_Log           -1.919072e-03     7.016380e-01       0.997895   1.000000
# cobas_Ct             6.622313e-04    -6.967892e-01      -0.997716  -0.999568
# cobas_IC_Ct         -4.518660e-02    -3.240526e-02      -0.467083  -0.458389
# AmpliPrep_Ct        -8.880236e-03    -7.336041e-01      -0.997104  -0.997036
# AmpliPrep_IC_Ct      1.835306e-02     2.927725e-02       0.087004   0.106534
# Log_Dilution_Factor  0.000000e+00     7.074817e-01       0.998344   0.998921
#
#                      cobas_Ct  cobas_IC_Ct  AmpliPrep_Ct  AmpliPrep_IC_Ct  \
# Run                  0.000662    -0.045187     -0.008880         0.018353
# Dilution_Factor     -0.696789    -0.032405     -0.733604         0.029277
# AmpliPrep_Log       -0.997716    -0.467083     -0.997104         0.087004
# cobas_Log           -0.999568    -0.458389     -0.997036         0.106534
# cobas_Ct             1.000000     0.483055      0.996833        -0.100122
# cobas_IC_Ct          0.483055     1.000000      0.447703         0.126600
# AmpliPrep_Ct         0.996833     0.447703      1.000000        -0.092569
# AmpliPrep_IC_Ct     -0.100122     0.126600     -0.092569         1.000000
# Log_Dilution_Factor -0.999133    -0.474553     -0.997708         0.101938
#
#                      Log_Dilution_Factor
# Run                             0.000000
# Dilution_Factor                 0.707482
# AmpliPrep_Log                   0.998344
# cobas_Log                       0.998921
# cobas_Ct                       -0.999133
# cobas_IC_Ct                    -0.474553
# AmpliPrep_Ct                   -0.997708
# AmpliPrep_IC_Ct                 0.101938
# Log_Dilution_Factor             1.000000
# 0.997160019241
